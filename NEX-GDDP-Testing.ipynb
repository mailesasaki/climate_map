# %%
import ee
import pandas as pd
import wxee
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import xee
import xarray as xr

# %% [markdown]
# # Processing Script

# %%
def nexgddpcmip6_processing(year_start, year_end, variable, scenario ):
    model_list = ['ACCESS-CM2', 'ACCESS-ESM1-5', 'BCC-CSM2-MR', 'CESM2', 'CESM2-WACCM', 'CMCC-CM2-SR5', 'CMCC-ESM2',
                  'CNRM-CM6-1', 'CNRM-ESM2-1', 'CanESM5', 'EC-Earth3', 'EC-Earth3-Veg-LR', 'FGOALS-g3', 'GFDL-CM4',
                  'GFDL-ESM4', 'GISS-E2-1-G', 'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM', 'IITM-ESM', 'INM-CM4-8', 'INM-CM5-0',
                  'IPSL-CM6A-LR', 'KACE-1-0-G', 'KIOST-ESM', 'MIROC-ES2L', 'MIROC6', 'MPI-ESM1-2-HR', 'MPI-ESM1-2-LR',
                  'MRI-ESM2-0', 'NESM3', 'NorESM2-LM', 'NorESM2-MM', 'TaiESM1', 'UKESM1-0-LL']
    scenario_list = ['historical', 'ssp245', 'ssp585']

    # Trigger the authentication flow.
    ee.Authenticate()

    # Initialize the library.
    ee.Initialize(project='ee-mailemsasaki')
    
    # Import NEX-GDDP-CMIP6
    nexgddp = ee.ImageCollection("NASA/GDDP-CMIP6")

    # Dates
    i_date = str(year_start) + '-01-01'
    f_date = str(year_end)   + '-12-31'
    
    # Picking out the Illinois region
    illinois = ee.Geometry.Rectangle([267.2,36,274,43.5])

    dataset_list = []
    for model in model_list:
        if model == 'GFDL-CM4':
            nexgddp_filtered = (nexgddp.select(variable).filterDate(i_date, f_date)
                     .filter(ee.Filter.eq('model',model)).filter(ee.Filter.eq('scenario',scenario))
                                .filter(ee.Filter.eq('grid_label','gr1')))
        else:
            # Filtering out the dataset we want
            nexgddp_filtered = (nexgddp.select(variable).filterDate(i_date, f_date)
                         .filter(ee.Filter.eq('model',model)).filter(ee.Filter.eq('scenario',scenario)))
        if nexgddp_filtered.size().getInfo() > 0:
            filtered_dataset = xr.open_dataset(nexgddp_filtered, engine='ee', scale=0.25, geometry=illinois,
                                                 projection=nexgddp_filtered.first().select(0).projection(),
                                                 use_cftime=True, fast_time_slicing=True)
            filtered_dataset['model'] = model
            print(model)
            filtered_dataset.load()
            dataset_list.append(filtered_dataset)
    
    dataset = xr.concat(dataset_list, dim='model', coords='minimal', compat='override')
    
    # Changing from -180-180 to 0-360 longitude scale
    dataset = dataset.assign_coords({"lon":dataset.lon%360})
    
    return dataset

# %%
test_nexgddp = nexgddpcmip6_processing(2015,2100,'sfcWind','ssp585')
# Out:
# ACCESS-CM2
# ACCESS-ESM1-5
# BCC-CSM2-MR
# CESM2
# CESM2-WACCM
# CMCC-CM2-SR5
# CMCC-ESM2
# CNRM-CM6-1
# CNRM-ESM2-1
# CanESM5
# EC-Earth3
# EC-Earth3-Veg-LR
# FGOALS-g3
# GFDL-CM4
# GFDL-ESM4
# GISS-E2-1-G
# HadGEM3-GC31-LL
# HadGEM3-GC31-MM
# IITM-ESM
# INM-CM4-8
# INM-CM5-0
# IPSL-CM6A-LR
# KACE-1-0-G
# KIOST-ESM
# MIROC-ES2L
# MIROC6
# MPI-ESM1-2-HR
# MPI-ESM1-2-LR
# MRI-ESM2-0
# NESM3
# NorESM2-LM
# NorESM2-MM
# TaiESM1
# UKESM1-0-LL

# %%
test_nexgddp
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 31410, lon: 27, lat: 30, model: 34)
# Coordinates:
#   * time     (time) datetime64[ns] 2015-01-01 2015-01-02 ... 2100-12-30
#   * lon      (lon) float64 267.3 267.6 267.8 268.1 ... 273.1 273.3 273.6 273.8
#   * lat      (lat) float64 43.43 43.18 42.93 42.68 ... 36.93 36.68 36.43 36.18
#   * model    (model) <U16 'ACCESS-CM2' 'ACCESS-ESM1-5' ... 'UKESM1-0-LL'
# Data variables:
#     sfcWind  (model, time, lon, lat) float32 3.755 3.826 3.739 ... 3.137 3.04
# Attributes:
#     crs:      EPSG:4326

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
test_nexgddp.sfcWind.sel(time='2019-06-10').mean('model').plot.pcolormesh(x='lon',y='lat')
#ax.set_extent([-91,-87.73,37.02,42.52], crs=ccrs.PlateCarree())
ax.add_feature(cfeature.STATES)

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
test_nexgddp.sfcWind.sel(time='2019-06-10').mean('model').plot.pcolormesh(x='lon',y='lat')
#ax.set_extent([-91,-87.73,37.02,42.52], crs=ccrs.PlateCarree())
ax.add_feature(cfeature.STATES)

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
test_nexgddp.sfcWind.sel(time='2019-12-10').mean('model').plot.pcolormesh(x='lon',y='lat')
#ax.set_extent([-91,-87.73,37.02,42.52], crs=ccrs.PlateCarree())
ax.add_feature(cfeature.STATES)

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
test_nexgddp.sfcWind.sel(time='2019-12-10').mean('model').plot.pcolormesh(x='lon',y='lat')
#ax.set_extent([-91,-87.73,37.02,42.52], crs=ccrs.PlateCarree())
ax.add_feature(cfeature.STATES)

# %% [markdown]
# # Google Earth Engine - XEE

# %%
# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize(project='ee-mailemsasaki')

# %%
# Import the MODIS land cover collection.
nexgddp = ee.ImageCollection("NASA/GDDP-CMIP6")
nexgddp

# %%
print(nexgddp.first().propertyNames().removeAll(['system:time_start','system:index','isodate']).getInfo())
# Out:
# ['month', 'scenario', 'year', 'system:footprint', 'system:time_end', 'system:version', 'system:id', 'model', 'system:asset_size', 'day', 'system:bands', 'system:band_names']

# %%
nexgddp
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 nexgddp.filter(ee.Filter.eq('system:version'))
#
# TypeError: Filter.eq() missing 1 required positional argument: 'value'

# %%
# Picking intial and end dates
i_date = '2017-06-01'

f_date = '2018-06-04'

#nexgddp_wind = nexgddp.select('sfcWind').filterDate(i_date, f_date)

# %%
# Picking out the Illinois Region
illinois = ee.Geometry.Rectangle([267.2,36,274,43.5])
#illinois = ee.Geometry.Rectangle(-91.6,42.6,-87.5,36.9)

# Filtering the dataset we want
wind_illinois = (ee.ImageCollection("NASA/GDDP-CMIP6").select('sfcWind').filterDate(i_date, f_date)
                 .filter(ee.Filter.eq('model','ACCESS-CM2')).filter(ee.Filter.eq('scenario','ssp245')))
#wind_illinois = nexgddp_wind.getRegion(illinois, 25000)

# %%
# Opening the dataset
wind_illinois_array = xr.open_dataset(wind_illinois, engine='ee', scale=0.25, geometry=illinois,
                                     projection=wind_illinois.first().select(0).projection())
wind_illinois_array
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 368, lon: 27, lat: 30)
# Coordinates:
#   * time     (time) datetime64[ns] 2017-06-01 2017-06-02 ... 2018-06-03
#   * lon      (lon) float64 -92.68 -92.43 -92.18 -91.93 ... -86.68 -86.43 -86.18
#   * lat      (lat) float64 43.43 43.18 42.93 42.68 ... 36.93 36.68 36.43 36.18
# Data variables:
#     sfcWind  (time, lon, lat) float32 ...
# Attributes:
#     crs:      EPSG:4326

# %%
# Changing from -180-180 to 0-360 longitude scale
wind_dataarray = wind_illinois_array.sfcWind.assign_coords({"lon":wind_illinois_array.lon%360})

# %%
wind_dataarray
# Out:
# <xarray.DataArray 'sfcWind' (time: 368, lon: 27, lat: 30)>
# array([[[3.002989, 3.083514, ..., 2.396026, 2.391735],
#         [3.055293, 3.127339, ..., 2.355554, 2.341709],
#         ...,
#         [5.01686 , 4.85514 , ..., 2.552777, 2.394531],
#         [5.067325, 4.895859, ..., 2.581004, 2.417129]],
#
#        [[2.060688, 2.124323, ..., 2.14923 , 2.236152],
#         [2.096815, 2.168814, ..., 2.17339 , 2.265448],
#         ...,
#         [3.836228, 3.799168, ..., 2.126127, 2.098911],
#         [3.84876 , 3.802753, ..., 2.053426, 2.022054]],
#
#        ...,
#
#        [[3.463192, 3.364504, ..., 1.671412, 1.70227 ],
#         [3.460863, 3.362483, ..., 1.625034, 1.657101],
#         ...,
#         [3.576798, 3.494301, ..., 1.014742, 0.986819],
#         [3.49931 , 3.417873, ..., 0.997471, 0.969829]],
#
#        [[4.604117, 4.548358, ..., 1.702484, 1.667856],
#         [4.610019, 4.577833, ..., 1.682615, 1.650285],
#         ...,
#         [3.975487, 4.082277, ..., 2.071834, 2.041609],
#         [4.020327, 4.172789, ..., 2.110031, 2.07984 ]]], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 2017-06-01 2017-06-02 ... 2018-06-03
#   * lon      (lon) float64 267.3 267.6 267.8 268.1 ... 273.1 273.3 273.6 273.8
#   * lat      (lat) float64 43.43 43.18 42.93 42.68 ... 36.93 36.68 36.43 36.18
# Attributes:
#     id:             sfcWind
#     data_type:      {'type': 'PixelType', 'precision': 'float'}
#     dimensions:     [1441, 600]
#     crs:            EPSG:4326
#     crs_transform:  [0.25, 0, -180, 0, -0.25, 90]

# %%
# Full time series mean - ACCESS-CM2 - ssp245 - sfcWind
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree())
wind_dataarray.mean('time').plot.pcolormesh(x='lon',y='lat')
#ax.set_extent([-91,-87.73,37.02,42.52], crs=ccrs.PlateCarree())
ax.add_feature(cfeature.STATES)
# Out:
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:googleapiclient.http:Sleeping 1.65 seconds before retry 1 of 5 for request: POST https://earthengine.googleapis.com/v1/projects/ee-mailemsasaki/image:computePixels?, after 503
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# ...
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:googleapiclient.http:Sleeping 1.29 seconds before retry 1 of 5 for request: POST https://earthengine.googleapis.com/v1/projects/ee-mailemsasaki/image:computePixels?, after 503
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:googleapiclient.http:Sleeping 1.99 seconds before retry 1 of 5 for request: POST https://earthengine.googleapis.com/v1/projects/ee-mailemsasaki/image:computePixels?, after 503
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:root:Xee is indexing into the ImageCollection beyond 10000 images. This operation can be slow. To improve performance, consider filtering the ImageCollection prior to using Xee or enabling fast_time_slicing.
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: earthengine.googleapis.com. Connection pool size: 10

# %%
# 2018-05-30 - ACCESS-CM2 - ssp245 - sfcWind
plt.rcParams['figure.figsize'] = [12, 7]
ax = plt.axes(projection=ccrs.PlateCarree())
wind_dataarray.sel(time='2018-05-30').plot.pcolormesh(x='lon',y='lat')
#ax.set_extent([-91,-87.73,37.02,42.52], crs=ccrs.PlateCarree())
ax.add_feature(cfeature.STATES)

# %%
# Making sure saving to a netcdf works
wind_dataarray.to_netcdf('/data/keeling/a/mailes2/a/NEX-GDDP-CMIP6_ACCESS-CM2_ssp370_illinois.nc')

# %% [markdown]
# # WXEE Tutorial

# %%
gridmet = ee.ImageCollection("IDAHO_EPSCOR/GRIDMET")

# %%
collection = gridmet.filterDate("2020-09-05", "2020-09-11")

# %%
# The coordinate reference system to use (NAD83 Albers CONUS)
crs = "EPSG:5070"
# Spatial resolution in CRS units (meters)
scale = 20_000

# %%
arr = collection.wx.to_xarray(scale=scale, crs=crs)
# Out:
# Requesting data:   0%|          | 0/6 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
hdw = arr.vs * arr.vpd

hdw.plot(col="time", col_wrap=3, cmap="magma", figsize=(15, 6))

# %% [markdown]
# # AWS S3

# %%
import s3fs
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import io  # Import the io module

# %% [markdown]
# # WXEE

# %%
wind_illinois_array = (wind_illinois.select('sfcWind'))
                       #.filterBounds(illinois))
wind_illinois_array = wind_illinois_array.wx.to_xarray(region=illinois, scale=25_000)
#wind_illinois_array = wind_illinois_array.wx.to_time_series()
# Out:
# Requesting data:   0%|          | 0/105 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [100], in <cell line: 3>()
#       1 wind_illinois_array = (wind_illinois.select('sfcWind'))
#       2                        #.filterBounds(illinois))
# ----> 3 wind_illinois_array = wind_illinois_array.wx.to_xarray(region=illinois, scale=25_000)
#
# File ~/miniconda3/envs/earthengine/lib/python3.10/site-packages/wxee/collection.py:117, in ImageCollection.to_xarray(self, path, region, scale, crs, masked, nodata, num_cores, progress, max_attempts)
#      72 """Convert an image collection to an xarray.Dataset. The :code:`system:time_start` property of each image in the
#      73 collection is used to arrange the time dimension, and each image variable is loaded as a separate array in
#      74 the dataset.
#    (...)
#     114 >>> col.wx.to_xarray(scale=40000, crs="EPSG:5070", nodata=-9999)
#     115 """
#     116 with tempfile.TemporaryDirectory(prefix=constants.TMP_PREFIX) as tmp:
# --> 117     files = self._obj.wx.to_tif(
#     118         out_dir=tmp,
#     119         region=region,
#     120         scale=scale,
#     121         crs=crs,
#     122         file_per_band=True,
#     123         masked=masked,
#     124         nodata=nodata,
#     125         num_cores=num_cores,
#     126         progress=progress,
#     127         max_attempts=max_attempts,
#     128     )
#     130     ds = _dataset_from_files(files, masked, nodata)
#     132 if path:
#
# File ~/miniconda3/envs/earthengine/lib/python3.10/site-packages/wxee/collection.py:212, in ImageCollection.to_tif(self, out_dir, prefix, region, scale, crs, file_per_band, masked, nodata, num_cores, progress, max_attempts)
#     208 with Parallel(n_jobs=num_cores, backend="threading") as p:
#     209     with parallel_tqdm(
#     210         tqdm(desc="Requesting data", total=n, disable=not progress)
#     211     ):
# --> 212         urls = p(
#     213             delayed(img.wx._get_url)(
#     214                 region, scale, crs, file_per_band, nodata, max_attempts
#     215             )
#     216             for img in imgs
#     217         )
#     219     with parallel_tqdm(
#     220         tqdm(desc="Downloading data", total=n, disable=not progress)
#     221     ):
#     222         img_urls = zip(imgs, urls)
#
# File ~/miniconda3/envs/earthengine/lib/python3.10/site-packages/joblib/parallel.py:1054, in Parallel.__call__(self, iterable)
#    1051     self._iterating = False
#    1053 with self._backend.retrieval_context():
# -> 1054     self.retrieve()
#    1055 # Make sure that we get a last message telling us we are done
#    1056 elapsed_time = time.time() - self._start_time
#
# File ~/miniconda3/envs/earthengine/lib/python3.10/site-packages/joblib/parallel.py:933, in Parallel.retrieve(self)
#     931 try:
#     932     if getattr(self._backend, 'supports_timeout', False):
# --> 933         self._output.extend(job.get(timeout=self.timeout))
#     934     else:
#     935         self._output.extend(job.get())
#
# File ~/miniconda3/envs/earthengine/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/miniconda3/envs/earthengine/lib/python3.10/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/miniconda3/envs/earthengine/lib/python3.10/threading.py:600, in Event.wait(self, timeout)
#     598 signaled = self._flag
#     599 if not signaled:
# --> 600     signaled = self._cond.wait(timeout)
#     601 return signaled
#
# File ~/miniconda3/envs/earthengine/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
