# %%
import pandas as pd

# %%
svi = pd.read_csv('/data/keeling/a/mailes2/a/SVI/Illinois.csv')
svi
# Out:
#       ST     STATE ST_ABBR  STCNTY           COUNTY         FIPS  \
# 0     17  Illinois      IL   17001     Adams County  17001000100
# 1     17  Illinois      IL   17001     Adams County  17001000201
# 2     17  Illinois      IL   17001     Adams County  17001000202
# 3     17  Illinois      IL   17001     Adams County  17001000400
# 4     17  Illinois      IL   17001     Adams County  17001000500
# ...   ..       ...     ...     ...              ...          ...
# 3258  17  Illinois      IL   17203  Woodford County  17203030501
# 3259  17  Illinois      IL   17203  Woodford County  17203030502
# 3260  17  Illinois      IL   17203  Woodford County  17203030601
# 3261  17  Illinois      IL   17203  Woodford County  17203030602
# 3262  17  Illinois      IL   17203  Woodford County  17203030700
#
#                                             LOCATION  AREA_SQMI  E_TOTPOP  \
# 0             Census Tract 1; Adams County; Illinois   5.439075      4509
# ...

# %%
svi.columns.values
# Out:
# array(['ST', 'STATE', 'ST_ABBR', 'STCNTY', 'COUNTY', 'FIPS', 'LOCATION',
#        'AREA_SQMI', 'E_TOTPOP', 'M_TOTPOP', 'E_HU', 'M_HU', 'E_HH',
#        'M_HH', 'E_POV150', 'M_POV150', 'E_UNEMP', 'M_UNEMP', 'E_HBURD',
#        'M_HBURD', 'E_NOHSDP', 'M_NOHSDP', 'E_UNINSUR', 'M_UNINSUR',
#        'E_AGE65', 'M_AGE65', 'E_AGE17', 'M_AGE17', 'E_DISABL', 'M_DISABL',
#        'E_SNGPNT', 'M_SNGPNT', 'E_LIMENG', 'M_LIMENG', 'E_MINRTY',
#        'M_MINRTY', 'E_MUNIT', 'M_MUNIT', 'E_MOBILE', 'M_MOBILE',
#        'E_CROWD', 'M_CROWD', 'E_NOVEH', 'M_NOVEH', 'E_GROUPQ', 'M_GROUPQ',
#        'EP_POV150', 'MP_POV150', 'EP_UNEMP', 'MP_UNEMP', 'EP_HBURD',
#        'MP_HBURD', 'EP_NOHSDP', 'MP_NOHSDP', 'EP_UNINSUR', 'MP_UNINSUR',
#        'EP_AGE65', 'MP_AGE65', 'EP_AGE17', 'MP_AGE17', 'EP_DISABL',
#        'MP_DISABL', 'EP_SNGPNT', 'MP_SNGPNT', 'EP_LIMENG', 'MP_LIMENG',
#        'EP_MINRTY', 'MP_MINRTY', 'EP_MUNIT', 'MP_MUNIT', 'EP_MOBILE',
# ...

# %%
svi_overall = svi['RPL_THEMES'] # SVI Value
svi_overall
# Out:
# 0       0.5155
# 1       0.5505
# 2       0.2356
# 3       0.8135
# 4       0.8012
#          ...
# 3258    0.1330
# 3259    0.1982
# 3260    0.5364
# 3261    0.0931
# 3262    0.4949
# Name: RPL_THEMES, Length: 3263, dtype: float64

# %%
ejscreen = pd.read_csv('/data/keeling/a/mailes2/a/SVI/EJScreen_2024_Tract_StatePct_with_AS_CNMI_GU_VI.csv')
ejscreen_IL = ejscreen[ejscreen['ST_ABBREV'] == 'IL']
ejscreen_IL
# Out:
# /tmp/ipykernel_1494/1177162282.py:1: DtypeWarning: Columns (173,177,182,183,184,185,187,193,194,195,196,197,198,199,200,201,203,204,205,207,209,211,213,215,216,217,218,219,220,221) have mixed types. Specify dtype option on import or set low_memory=False.
#   ejscreen = pd.read_csv('/data/keeling/a/mailes2/a/SVI/EJScreen_2024_Tract_StatePct_with_AS_CNMI_GU_VI.csv')
#         OID_            ID STATE_NAME ST_ABBREV        CNTY_NAME  REGION  \
# 25003  25004  1.700100e+10   ILLINOIS        IL     Adams County     5.0
# 25004  25005  1.700100e+10   ILLINOIS        IL     Adams County     5.0
# 25005  25006  1.700100e+10   ILLINOIS        IL     Adams County     5.0
# 25006  25007  1.700100e+10   ILLINOIS        IL     Adams County     5.0
# 25007  25008  1.700100e+10   ILLINOIS        IL     Adams County     5.0
# ...      ...           ...        ...       ...              ...     ...
# 28263  28264  1.720303e+10   ILLINOIS        IL  Woodford County     5.0
# ...

# %%
ejscreen_IL.columns.values
# Out:
# array(['OID_', 'ID', 'STATE_NAME', 'ST_ABBREV', 'CNTY_NAME', 'REGION',
#        'ACSTOTPOP', 'ACSIPOVBAS', 'ACSEDUCBAS', 'ACSTOTHH', 'ACSTOTHU',
#        'ACSUNEMPBAS', 'ACSDISABBAS', 'DEMOGIDX_2', 'DEMOGIDX_5',
#        'PEOPCOLOR', 'PEOPCOLORPCT', 'LOWINCOME', 'LOWINCPCT',
#        'UNEMPLOYED', 'UNEMPPCT', 'DISABILITY', 'DISABILITYPCT', 'LINGISO',
#        'LINGISOPCT', 'LESSHS', 'LESSHSPCT', 'UNDER5', 'UNDER5PCT',
#        'OVER64', 'OVER64PCT', 'LIFEEXPPCT', 'PM25', 'OZONE', 'DSLPM',
#        'RSEI_AIR', 'PTRAF', 'PRE1960', 'PRE1960PCT', 'PNPL', 'PRMP',
#        'PTSDF', 'UST', 'PWDIS', 'NO2', 'DWATER', 'D2_PM25', 'D5_PM25',
#        'D2_OZONE', 'D5_OZONE', 'D2_DSLPM', 'D5_DSLPM', 'D2_RSEI_AIR',
#        'D5_RSEI_AIR', 'D2_PTRAF', 'D5_PTRAF', 'D2_LDPNT', 'D5_LDPNT',
#        'D2_PNPL', 'D5_PNPL', 'D2_PRMP', 'D5_PRMP', 'D2_PTSDF', 'D5_PTSDF',
#        'D2_UST', 'D5_UST', 'D2_PWDIS', 'D5_PWDIS', 'D2_NO2', 'D5_NO2',
# ...
